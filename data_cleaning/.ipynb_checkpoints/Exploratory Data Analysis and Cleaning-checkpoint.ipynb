# %%
import pandas as pd
import datetime
import time
from scipy.spatial import distance

# %%
test_df = pd.read_csv("../raw_data/JC-202008-citibike-tripdata.csv")

test_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1               236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2               384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3              1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4              5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# 0                  3185          City Hall               40.717733
# 1                  3186      Grove St PATH               40.719586
# 2                  3186      Grove St PATH               40.719586
# 3                  3185          City Hall               40.717733
# 4                  3185          City Hall               40.717733
# ...                 ...                ...                     ...
# 43262              3186      Grove St PATH               40.719586
# 43263              3481            York St               40.716490
# 43264              3195            Sip Ave               40.730897
# 43265              3195            Sip Ave               40.730897
# 43266              3211         Newark Ave               40.721525
#
#        start station longitude  end station id end station name  \
# 0                   -74.043845            3185        City Hall
# 1                   -74.043117            3270  Jersey & 6th St
# 2                   -74.043117            3203    Hamilton Park
# 3                   -74.043845            3185        City Hall
# 4                   -74.043845            3185        City Hall
# ...                        ...             ...              ...
# 43262               -74.043117            3279      Dixon Mills
# 43263               -74.041050            3187        Warren St
# 43264               -74.063913            3194  McGinley Square
# 43265               -74.063913            3194  McGinley Square
# 43266               -74.046305            3270  Jersey & 6th St
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.717733             -74.043845   42303    Customer
# 1                 40.725289             -74.045572   44989  Subscriber
# 2                 40.727596             -74.044247   41696  Subscriber
# 3                 40.717733             -74.043845   42310    Customer
# 4                 40.717733             -74.043845   42346    Customer
# ...                     ...                    ...     ...         ...
# 43262             40.721630             -74.049968   44787  Subscriber
# 43263             40.721124             -74.038051   19153  Subscriber
# 43264             40.725340             -74.067622   42434  Subscriber
# 43265             40.725340             -74.067622   44226  Subscriber
# 43266             40.725289             -74.045572   42437  Subscriber
#
#        birth year  gender
# 0            1994       2
# 1            1996       1
# 2            1984       2
# 3            1993       1
# 4            1995       2
# ...           ...     ...
# 43262        1977       1
# 43263        1986       1
# 43264        1960       1
# 43265        1994       1
# 43266        1984       2
#
# [43267 rows x 15 columns]

# %%
test_df["rider_age"] = test_df["birth year"].apply(lambda x: datetime.datetime.now().year - x)


print(test_df["rider_age"].min())
#clear issues with maximum rider age...
print(test_df["rider_age"].max())
test_df
# Out:
# 16
# 132
#        tripduration                 starttime                  stoptime  \
# 0               561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1               236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2               384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3              1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4              5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# 0                  3185          City Hall               40.717733
# 1                  3186      Grove St PATH               40.719586
# 2                  3186      Grove St PATH               40.719586
# 3                  3185          City Hall               40.717733
# 4                  3185          City Hall               40.717733
# ...                 ...                ...                     ...
# 43262              3186      Grove St PATH               40.719586
# 43263              3481            York St               40.716490
# 43264              3195            Sip Ave               40.730897
# 43265              3195            Sip Ave               40.730897
# 43266              3211         Newark Ave               40.721525
#
#        start station longitude  end station id end station name  \
# 0                   -74.043845            3185        City Hall
# 1                   -74.043117            3270  Jersey & 6th St
# 2                   -74.043117            3203    Hamilton Park
# 3                   -74.043845            3185        City Hall
# 4                   -74.043845            3185        City Hall
# ...                        ...             ...              ...
# 43262               -74.043117            3279      Dixon Mills
# 43263               -74.041050            3187        Warren St
# 43264               -74.063913            3194  McGinley Square
# 43265               -74.063913            3194  McGinley Square
# 43266               -74.046305            3270  Jersey & 6th St
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.717733             -74.043845   42303    Customer
# 1                 40.725289             -74.045572   44989  Subscriber
# 2                 40.727596             -74.044247   41696  Subscriber
# 3                 40.717733             -74.043845   42310    Customer
# 4                 40.717733             -74.043845   42346    Customer
# ...                     ...                    ...     ...         ...
# 43262             40.721630             -74.049968   44787  Subscriber
# 43263             40.721124             -74.038051   19153  Subscriber
# 43264             40.725340             -74.067622   42434  Subscriber
# 43265             40.725340             -74.067622   44226  Subscriber
# 43266             40.725289             -74.045572   42437  Subscriber
#
#        birth year  gender  rider_age
# 0            1994       2         26
# 1            1996       1         24
# 2            1984       2         36
# 3            1993       1         27
# 4            1995       2         25
# ...           ...     ...        ...
# 43262        1977       1         43
# 43263        1986       1         34
# 43264        1960       1         60
# 43265        1994       1         26
# 43266        1984       2         36
#
# [43267 rows x 16 columns]

# %%
test_df["rider_age"].value_counts()
# Out:
# 51     8570
# 28     2171
# 31     2048
# 30     2023
# 32     1850
#        ...
# 90        3
# 132       2
# 72        2
# 75        1
# 78        1
# Name: rider_age, Length: 62, dtype: int64

# %%
rider_ages = test_df["rider_age"].value_counts().sort_index()
rider_ages
# Out:
# 16       5
# 17      26
# 18     115
# 19     230
# 20     304
#       ...
# 74       7
# 75       1
# 78       1
# 90       3
# 132      2
# Name: rider_age, Length: 62, dtype: int64

# %%
#some issues for data where ages are too high, maybe too many values (duplicates?) for age = 51
#can compare to other data sets from previous months, too
rider_ages.plot(kind="bar")

# %%
rider_ages.plot()

# %%
print(test_df["usertype"].value_counts())
# Out:
# Subscriber    26328
# Customer      16939
# Name: usertype, dtype: int64

# %%
print(test_df.loc[test_df["rider_age"] == 51]["usertype"].value_counts())
# Out:
# Customer      8093
# Subscriber     477
# Name: usertype, dtype: int64

# %%
print(test_df.loc[test_df["rider_age"] == 51]["start station name"].value_counts())
# Out:
# Newport Pkwy                  669
# Liberty Light Rail            644
# Marin Light Rail              393
# Grove St PATH                 385
# Columbus Dr at Exchange Pl    363
# Newport PATH                  357
# Harborside                    344
# Sip Ave                       316
# Washington St                 297
# Paulus Hook                   270
# Hamilton Park                 269
# Warren St                     257
# JC Medical Center             247
# Morris Canal                  241
# Columbus Drive                222
# Van Vorst Park                192
# Lincoln Park                  166
# Newark Ave                    166
# Hoboken Ave at Monmouth St    156
# City Hall                     150
# Baldwin at Montgomery         146
# Heights Elevator              130
# Communipaw & Berry Lane       126
# York St                       121
# Pershing Field                119
# Brunswick St                  119
# Grand St                      113
# Astor Place                   112
# McGinley Square               105
# Manila & 1st                   99
# Jersey & 3rd                   91
# Journal Square                 89
# Hilltop                        88
# Montgomery St                  88
# Jersey & 6th St                86
# Bergen Ave                     71
# Oakland Ave                    71
# Lafayette Park                 70
# Union St                       69
# Essex Light Rail               68
# Dixon Mills                    68
# Riverview Park                 63
# Brunswick & 6th                59
# Fairmount Ave                  55
# Jackson Square                 49
# 5 Corners Library              43
# Monmouth and 6th               37
# Christ Hospital                34
# Dey St                         30
# Leonard Gordon Park            24
# Glenwood Ave                   23
# Name: start station name, dtype: int64

# %%
print(test_df.loc[test_df["rider_age"] == 51]["end station name"].value_counts())
# Out:
# Liberty Light Rail                680
# Newport Pkwy                      657
# Grove St PATH                     454
# Newport PATH                      363
# Columbus Dr at Exchange Pl        362
# Marin Light Rail                  359
# Harborside                        334
# Washington St                     303
# JC Medical Center                 289
# Hamilton Park                     283
# Paulus Hook                       278
# Morris Canal                      252
# Warren St                         249
# Sip Ave                           240
# Columbus Drive                    213
# Lincoln Park                      199
# Van Vorst Park                    181
# Newark Ave                        163
# Hoboken Ave at Monmouth St        162
# City Hall                         149
# Communipaw & Berry Lane           144
# Pershing Field                    123
# Montgomery St                     121
# Baldwin at Montgomery             116
# Manila & 1st                      114
# Astor Place                       114
# Grand St                          114
# Heights Elevator                  103
# Brunswick St                      100
# York St                            99
# Lafayette Park                     89
# Jersey & 3rd                       86
# Hilltop                            77
# Union St                           77
# Jackson Square                     77
# Essex Light Rail                   75
# Dixon Mills                        73
# Jersey & 6th St                    73
# Riverview Park                     71
# McGinley Square                    70
# Brunswick & 6th                    68
# Bergen Ave                         62
# Fairmount Ave                      55
# Oakland Ave                        47
# Journal Square                     41
# Monmouth and 6th                   39
# Christ Hospital                    34
# Leonard Gordon Park                34
# 5 Corners Library                  33
# Dey St                             33
# Glenwood Ave                       28
# St James Pl & Pearl St              2
# W 169 St & Fort Washington Ave      2
# Front St & Maiden Ln                1
# DeKalb Ave & Hudson Ave             1
# Watts St & Greenwich St             1
# Wall St & South St                  1
# E 123 St & Lexington Ave            1
# Christopher St & Greenwich St       1
# Name: end station name, dtype: int64

# %%
#test data to get approx. mph over ride duration - may have off values, probably be good to know
check_dist = distance.cdist([[40.719586, -74.043117]], [[40.727596, -74.044247]], 'cityblock')
print(check_dist*69*3600/(384))

def getDist(row):
    start = [row["start station latitude"], row["start station longitude"]]
    end = [row["end station latitude"], row["end station longitude"]]
    sec = row["tripduration"]
    total_coord_dist = distance.cdist([start], [end], 'cityblock')
    return (total_coord_dist*69*3600/(sec))[0][0]
# Out:
# [[5.9124375]]

# %%
#add average speed calculated column
test_df["avg_speed"] = test_df.apply(lambda row: getDist(row), axis=1)
test_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1               236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2               384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3              1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4              5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
# ...             ...                       ...                       ...
# 43262           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 43263           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 43264           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 43265           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 43266           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#        start station id start station name  start station latitude  \
# 0                  3185          City Hall               40.717733
# 1                  3186      Grove St PATH               40.719586
# 2                  3186      Grove St PATH               40.719586
# 3                  3185          City Hall               40.717733
# 4                  3185          City Hall               40.717733
# ...                 ...                ...                     ...
# 43262              3186      Grove St PATH               40.719586
# 43263              3481            York St               40.716490
# 43264              3195            Sip Ave               40.730897
# 43265              3195            Sip Ave               40.730897
# 43266              3211         Newark Ave               40.721525
#
#        start station longitude  end station id end station name  \
# 0                   -74.043845            3185        City Hall
# 1                   -74.043117            3270  Jersey & 6th St
# 2                   -74.043117            3203    Hamilton Park
# 3                   -74.043845            3185        City Hall
# 4                   -74.043845            3185        City Hall
# ...                        ...             ...              ...
# 43262               -74.043117            3279      Dixon Mills
# 43263               -74.041050            3187        Warren St
# 43264               -74.063913            3194  McGinley Square
# 43265               -74.063913            3194  McGinley Square
# 43266               -74.046305            3270  Jersey & 6th St
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.717733             -74.043845   42303    Customer
# 1                 40.725289             -74.045572   44989  Subscriber
# 2                 40.727596             -74.044247   41696  Subscriber
# 3                 40.717733             -74.043845   42310    Customer
# 4                 40.717733             -74.043845   42346    Customer
# ...                     ...                    ...     ...         ...
# 43262             40.721630             -74.049968   44787  Subscriber
# 43263             40.721124             -74.038051   19153  Subscriber
# 43264             40.725340             -74.067622   42434  Subscriber
# 43265             40.725340             -74.067622   44226  Subscriber
# 43266             40.725289             -74.045572   42437  Subscriber
#
#        birth year  gender  rider_age  avg_speed
# 0            1994       2         26   0.000000
# 1            1996       1         24   8.585812
# 2            1984       2         36   5.912241
# 3            1993       1         27   0.000000
# 4            1995       2         25   0.000000
# ...           ...     ...        ...        ...
# 43262        1977       1         43  13.638062
# 43263        1986       1         34   4.739876
# 43264        1960       1         60   7.992501
# 43265        1994       1         26  11.567036
# 43266        1984       2         36   3.354382
#
# [43267 rows x 17 columns]

# %%
bike_speeds = test_df["avg_speed"].sort_values()
bike_speeds = bike_speeds.reset_index(drop=True)
bike_speeds.plot(kind="hist")
